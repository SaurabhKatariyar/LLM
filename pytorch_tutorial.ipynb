# %% [markdown]
# <a href="https://colab.research.google.com/github/SaurabhKatariyar/LLM/blob/main/pytorch_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
torch.__version__
# Out:
# '2.10.0+cu128'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
tensor0d = torch.tensor(1)

# %%
tensor0d.dtype
# Out:
# torch.int64

# %%
floatvev = torch.tensor([1.1,1.2,1.3])

# %%
floatvev.dtype
# Out:
# torch.float32
